# %% [markdown]
# # Data Field Research

# %% [markdown]
# ## Business Understanding:
# Many people try to enter the data fields nowadays as it's a trinding career track and because of the emerging technologies that depend on data. And as it's sayed "Data is the Oil of this century".
# But while trying to enter this field many people can face too many obsticals that can lead them to change thier minds and try to shift to another career.
#
# That's why I have started to work on this project in order to have a clear understanding of the best practices that can be made in order to start a successful career in the data field.

# %%
#Importing liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Understanding:

# %% [markdown]
# ## Loading data into notebook

# %%
# Geathering the data
# Importing the 2022 survey data from Stack overflow webstie 
df = pd.read_csv("survey_results_public.csv")
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode  ... TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# 0       NaN  ...           NaN           NaN        NaN              NaN
# 1       NaN  ...           NaN           NaN        NaN              NaN
# 2        14  ...           NaN           NaN        NaN              NaN
# 3        20  ...           NaN           NaN        NaN              NaN
# 4         8  ...           NaN           NaN        NaN              NaN
#
#   TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0         NaN         NaN         NaN                    NaN
# 1         NaN         NaN         NaN               Too long
# 2         NaN         NaN         NaN  Appropriate in length
# 3         NaN         NaN         NaN  Appropriate in length
# 4         NaN         NaN         NaN               Too long
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                   Difficult                 NaN
# 2  Neither easy nor difficult             40205.0
# 3                        Easy            215232.0
# 4                        Easy                 NaN
#
# [5 rows x 79 columns]

# %%
# Assesing the data.
#inspecting the data by viewing it's shape, columns, and a preaf about the numiric columns.
df.shape
# Out:
# (73268, 79)

# %%
print(df.columns)
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
#        'Accessibility', 'MentalHealth', 'TBranch', 'ICorPM', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering',
#        'Onboarding', 'ProfessionalTech', 'TrueFalse_1', 'TrueFalse_2',
#        'TrueFalse_3', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use  \
# count   5742.000000  3.504000e+03                    0.0
# mean   37209.770637  2.853881e+18                    NaN
# std    21186.738273  1.689343e+20                    NaN
# min        3.000000  0.000000e+00                    NaN
# 25%    18657.250000  3.500000e+04                    NaN
# 50%    37755.500000  8.500000e+04                    NaN
# 75%    55936.500000  1.552500e+05                    NaN
# max    73268.000000  1.000000e+22                    NaN
#
#        VCHostingProfessional use      WorkExp  ConvertedCompYearly
# count                        0.0  3386.000000         3.462000e+03
# mean                         NaN    11.958949         1.753766e+05
# std                          NaN    10.110429         6.722665e+05
# min                          NaN     0.000000         7.000000e+00
# 25%                          NaN     4.000000         3.868800e+04
# 50%                          NaN     9.000000         7.122550e+04
# 75%                          NaN    17.000000         1.223930e+05
# max                          NaN    50.000000         1.500000e+07

# %% [markdown]
# ## Data Preparation:

# %% [markdown]
# ## Filtering data to only include Data Field job roles

# %%
# Cleaning the Data
# Creating a filter to extract all the DevTypes that contain the word data in it.
filter_data_jobs = lambda row: 'data' in row.lower()
mask = df['DevType'].str.lower().str.contains('data ').fillna(False)
df = df[mask]

# %%
df.head()
# Out:
#     ResponseId                                         MainBranch  \
# 2            3  I am not primarily a developer, but I write co...
# 39          40                     I am a developer by profession
# 40          41                     I am a developer by profession
# 41          42                     I am a developer by profession
# 50          51  I am not primarily a developer, but I write co...
#
#                                 Employment  \
# 2                      Employed, full-time
# 39                     Employed, full-time
# 40                     Employed, full-time
# 41                     Employed, full-time
# 50  Employed, full-time;Student, full-time
#
#                               RemoteWork                    CodingActivities  \
# 2   Hybrid (some remote, some in-person)                               Hobby
# 39  Hybrid (some remote, some in-person)                               Hobby
# 40  Hybrid (some remote, some in-person)       Hobby;Freelance/contract work
# 41  Hybrid (some remote, some in-person)        I don’t code outside of work
# 50                        Full in-person  Contribute to open-source projects
#
#                                               EdLevel  \
# 2     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 39    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 40                Associate degree (A.A., A.S., etc.)
# 41  Secondary school (e.g. American high school, G...
# 50    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                             LearnCode  \
# 2   Books / Physical media;Friend or family member...
# 39  Books / Physical media;Other online resources ...
# 40  Books / Physical media;Other online resources ...
# 41  Other online resources (e.g., videos, blogs, f...
# 50  Books / Physical media;Friend or family member...
#
#                                       LearnCodeOnline    LearnCodeCoursesCert  \
# 2   Technical documentation;Blogs;Programming Game...                     NaN
# 39  Technical documentation;Blogs;Written Tutorial...        Udemy;Codecademy
# 40  Technical documentation;Blogs;Written Tutorial...                     NaN
# 41  Technical documentation;Blogs;Written Tutorial...  Coursera;Udemy;Udacity
# 50  Technical documentation;Blogs;Written Tutorial...                     NaN
#
#    YearsCode  ...        TimeSearching               TimeAnswering  \
# 2         14  ...                  NaN                         NaN
# 39        24  ...                  NaN                         NaN
# 40        20  ...                  NaN                         NaN
# 41         3  ...  30-60 minutes a day         15-30 minutes a day
# 50        11  ...  15-30 minutes a day  Less than 15 minutes a day
#
#         Onboarding ProfessionalTech TrueFalse_1 TrueFalse_2 TrueFalse_3  \
# 2              NaN              NaN         NaN         NaN         NaN
# 39             NaN              NaN         NaN         NaN         NaN
# 40             NaN              NaN         NaN         NaN         NaN
# 41  Somewhat short              NaN         NaN         Yes         Yes
# 50             NaN              NaN         NaN         NaN         NaN
#
#              SurveyLength                  SurveyEase ConvertedCompYearly
# 2   Appropriate in length  Neither easy nor difficult             40205.0
# 39  Appropriate in length  Neither easy nor difficult                 NaN
# 40  Appropriate in length                        Easy            130000.0
# 41  Appropriate in length  Neither easy nor difficult             68160.0
# 50  Appropriate in length                        Easy                 NaN
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Evaluation:

# %% [markdown]
# ### 1- What is the most recommended way to enter the data science field?

# %%
# Analyzing the data.
# Trying to find the most common ways to learn coding.
jobs = df['LearnCode'].str.split(";")
jobs = jobs.explode()

jobs_count = jobs.value_counts().reset_index()
jobs_count
# Out:
#                                                index  LearnCode
# 0  Other online resources (e.g., videos, blogs, f...       4173
# 1            School (i.e., University, College, etc)       3806
# 2                             Books / Physical media       3525
# 3                    Online Courses or Certification       3000
# 4                                On the job training       2905
# 5                                          Colleague       1344
# 6                            Friend or family member        860
# 7                                    Coding Bootcamp        733
# 8                  Hackathons (virtual or in-person)        605
# 9                            Other (please specify):        321

# %% [markdown]
# ### 2- What are the most common programming languages to work with in the data field?

# %%
# Exploring the Top 10 Used languages in the data Science field.
LanguageHaveWorkedWith = df['LanguageHaveWorkedWith'].str.split(";")
LanguageHaveWorkedWith = LanguageHaveWorkedWith.explode()

LanguageHaveWorkedWith_count = LanguageHaveWorkedWith.value_counts().reset_index()
LanguageHaveWorkedWith_count[:10]
# Out:
#         index  LanguageHaveWorkedWith
# 0      Python                    4199
# 1         SQL                    3723
# 2  JavaScript                    2940
# 3    HTML/CSS                    2626
# 4  Bash/Shell                    1942
# 5        Java                    1485
# 6          C#                    1364
# 7         C++                    1340
# 8  TypeScript                    1213
# 9           R                    1199

# %%
# Exploring the Top 10 languages to be used in the future in the data Science field.
LanguageWantToWorkWith = df["LanguageWantToWorkWith"].str.split(";")
LanguageWantToWorkWith = LanguageWantToWorkWith.explode()
LanguageWantToWorkWith_count = LanguageWantToWorkWith.value_counts().reset_index()
LanguageWantToWorkWith_count[:10]
# Out:
#         index  LanguageWantToWorkWith
# 0      Python                    3688
# 1         SQL                    2801
# 2  JavaScript                    2098
# 3    HTML/CSS                    1682
# 4  Bash/Shell                    1329
# 5  TypeScript                    1301
# 6        Rust                    1198
# 7          Go                    1059
# 8          C#                    1026
# 9         C++                     981

# %% [markdown]
# ### 3- Which is most prefered working situation for data field workers?

# %%
# comparing the work sitiuations in the data field.
# Also visualizing the data we have.
values = df["RemoteWork"].value_counts()
values.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### 4- What is the Average time spent searching a day?

# %%
df['TimeSearching'].value_counts().reset_index()
# Out:
#                         index  TimeSearching
# 0         30-60 minutes a day           1253
# 1         15-30 minutes a day            900
# 2        60-120 minutes a day            587
# 3  Less than 15 minutes a day            342
# 4      Over 120 minutes a day            257
